# %% [markdown]
# ### Please make sure you have access rights for all resources and follow all the contribution guidelines.

# %% [markdown]
# ## To Know about the architecture of the complete project
#
# https://dev.azure.com/cgmwhh/ChildGrowthMonitor/_git/infrastructure?path=%2Foperations_manual.md&version=GBmaster&fullScreen=true

# %% [markdown]
# ## Step 1: Git Implementation
# Refer the readme to setup Git workflow [https://github.com/Welthungerhilfe/cgm-ml]

# %% [markdown]
# ## Step 2: JupyterHub Access
# - Get acces to jupyterhub https://hub.childgrowthmonitor.org
# - On the Terminal Clone the cgm-ml repo
#     git clone https://github.com/Welthungerhilfe/cgm-ml.git
# - cd cgm-ml

# %% [markdown]
# ## Step 3: Setting up the database
# - On terminal
# - cp /whhdata/dbconnection.json notebooks/cgm-ml/cgm_database
# - cd /notebooks/cgm-ml/cgm_database
# - Refer to [dbutils.py](cgm-ml/cgm_database/dbutils.py) for helpful database operations.

# %% [markdown]
# ## Some key points to lookout for
# - After changing your intital password on jupyterhub, the connection may close.
# - Azure portal and Azure devops share the same azure user object, so login data are always identical. Linux user objects are     independent of Azure user objects. changing your password in one system does NOT change the password in the other system.
# - Also, the two Jupyterhub linux VMs have independent user management, so role assignment, access rights, passwords might even    differ depending on whether you use the data scientist VM with GPU or the one without.
# - Jupyterhub user directories are temporary only and might be deleted at any time

# %%
import dbutils
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob2
from random import randint
from IPython.core.display import Image, display
import numpy as np
from skimage import transform,io
import cv2
import IPython

# Where to store outputs.
output_path = "/outputs"
output_path = "."

# Connect to database.
main_connector = dbutils.connect_to_main_database()

# %%
main_connector.get_columns("measurements")
# Out:
# ['id',
#  'measurement_id',
#  'person_id',
#  'qrcode',
#  'sex',
#  'type',
#  'age_days',
#  'height_cms',
#  'weight_kgs',
#  'muac_cms',
#  'head_circumference_cms',
#  'oedema',
#  'latitude',
#  'longitude',
#  'address',
#  'timestamp',
#  'deleted',
#  'deleted_by',
#  'visible',
#  'created_by']

# %%
main_connector.get_columns('image_data')
# Out:
# ['id',
#  'path',
#  'qrcode',
#  'last_updated',
#  'rejected_by_expert',
#  'had_error',
#  'error_message',
#  'width_px',
#  'height_px',
#  'blur_variance',
#  'has_face',
#  'measurement_id']

# %%
def imshow(img):
    _,ret = cv2.imencode('.jpg', img) 
    i = IPython.display.Image(data=ret)
    IPython.display.display(i)

# %%
training_path = "/whhdata/person/MH_WHH_0035/measurements/1537342371195/rgb/"
glob_search_path = os.path.join(training_path, "**/*.jpg")
jpg_paths = glob2.glob(glob_search_path)
print("jpg_paths", len(jpg_paths))
# Out:
# jpg_paths 94

# %% [markdown]
# ### Some random sample

# %%
index = randint(0,len(jpg_paths)-1)
img_filename = jpg_paths[index]
image = io.imread(img_filename)
print("File %s: %s" % (index, img_filename))
imshow(image)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-25f474fd064c> in <module>
#       1 index = randint(0,len(jpg_paths)-1)
#       2 img_filename = jpg_paths[index]
# ----> 3 image = io.imread(img_filename)
#       4 print("File %s: %s" % (index, img_filename))
#       5 imshow(image)
#
# /data/anaconda/envs/cgm/lib/python3.6/site-packages/skimage/io/_io.py in imread(fname, as_gray, plugin, flatten, **plugin_args)
#      59
#      60     with file_or_url_context(fname) as fname:
# ---> 61         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      62
#      63     if not hasattr(img, 'ndim'):
#
# /data/anaconda/envs/cgm/lib/python3.6/site-packages/skimage/io/manage_plugins.py in call_plugin(kind, *args, **kwargs)
#     208                                (plugin, kind))
#     209
# --> 210     return func(*args, **kwargs)
#     211
#     212
#
# /data/anaconda/envs/cgm/lib/python3.6/site-packages/imageio/core/functions.py in imread(uri, format, **kwargs)
#     219
#     220     # Get reader and read first
# --> 221     reader = read(uri, format, "i", **kwargs)
#     222     with reader:
#     223         return reader.get_data(0)
#
# /data/anaconda/envs/cgm/lib/python3.6/site-packages/imageio/core/functions.py in get_reader(uri, format, mode, **kwargs)
#     134         format = formats[format]
#     135     else:
# --> 136         format = formats.search_read_format(request)
#     137     if format is None:
#     138         raise ValueError(
#
# /data/anaconda/envs/cgm/lib/python3.6/site-packages/imageio/core/format.py in search_read_format(self, request)
#     677         # Select the first that can
#     678         for format in selected_formats:
# --> 679             if format.can_read(request):
#     680                 return format
#     681
#
# /data/anaconda/envs/cgm/lib/python3.6/site-packages/imageio/core/format.py in can_read(self, request)
#     183         Get whether this format can read data from the specified uri.
#     184         """
# --> 185         return self._can_read(request)
#     186
#     187     def can_write(self, request):
#
# /data/anaconda/envs/cgm/lib/python3.6/site-packages/imageio/plugins/pillow.py in _can_read(self, request)
#     102
#     103     def _can_read(self, request):
# --> 104         Image = self._init_pillow()
#     105         if request.mode[1] in (self.modes + "?"):
#     106             if self.plugin_id in Image.OPEN:
#
# /data/anaconda/envs/cgm/lib/python3.6/site-packages/imageio/plugins/pillow.py in _init_pillow(self)
#      96
#      97         if self.plugin_id in ("PNG", "JPEG", "BMP", "GIF", "PPM"):
# ---> 98             Image.preinit()
#      99         else:
#     100             Image.init()
#
# /data/anaconda/envs/cgm/lib/python3.6/site-packages/PIL/Image.py in preinit()
#     362     :exception KeyError: If the input mode was not a standard mode.
#     363     """
# --> 364     return len(ImageMode.getmode(mode).bands)
#     365
#     366
#
# /data/anaconda/envs/cgm/lib/python3.6/site-packages/PIL/PpmImagePlugin.py in <module>
#     165 Image.register_save(PpmImageFile.format, _save)
#     166
# --> 167 Image.register_extensions(PpmImageFile.format, [".pbm", ".pgm", ".ppm", ".pnm"])
#     168
#     169 Image.register_mime(PpmImageFile.format, "image/x-portable-anymap")
#
# AttributeError: module 'PIL.Image' has no attribute 'register_extensions'

# %%
main_connector.get_columns('point_cloud')
# Out:
# []

# %% [markdown]
# ## Function to display point cloud data

# %%
from cgmcore.utils import load_pcd_as_ndarray
from cgmcore.utils import render_pointcloud
def plot_pcd(pcd_path):
    pointcloud = load_pcd_as_ndarray(pcd_path)
    print("Loading... pointcloud with shape {}.".format(pointcloud.shape))
    render_pointcloud(pointcloud, "A pointcloud")
# Out:
# WARNING! VTK not available. This might limit the functionality.

# %%
pcd_path = "/whhdata/person/MH_WHH_0035/measurements/1537342371195/pc/pc_MH_WHH_0035_1537342371195_104_000.pcd"
plot_pcd(pcd_path)
# Out:
# Loading... pointcloud with shape (37451, 4).
